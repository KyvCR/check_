# %%
import requests as rs
import json
import pandas as pd

url = "https://covid-19.dataflowkit.com/v1"
url_all = "https://covid-19.dataflowkit.com/v1/world"


response = rs.get(url).json()
x = json.dumps(response, indent=2)
print(x)
# Out:
# [
#   {
#     "Active Cases_text": "+20,048",
#     "Country_text": "World",
#     "Last Update": "2023-07-04 06:19",
#     "New Cases_text": "+15",
#     "New Deaths_text": "0",
#     "Total Cases_text": "690,985,847",
#     "Total Deaths_text": "6,896,157",
#     "Total Recovered_text": "663,652,718"
#   },
#   {
#     "Active Cases_text": "",
#     "Country_text": "USA",
#     "Last Update": "2023-07-04 06:19",
#     "New Cases_text": "",
#     "New Deaths_text": "",
#     "Total Cases_text": "107,329,712",
#     "Total Deaths_text": "1,168,267",
#     "Total Recovered_text": "105,479,716"
#   },
#   {
#     "Active Cases_text": "",
#     "Country_text": "India",
#     "Last Update": "2023-07-04 06:19",
#     "New Cases_text": "",
#     "New Deaths_text": "",
#     "Total Cases_text": "44,994,281",
#     "Total Deaths_text": "531,907",
#     "Total Recovered_text": "44,460,884"
#   },
#   {
#     "Active Cases_text": "+2,631",
#     "Country_text": "France",
# ...

# %%
response1 = rs.get(url_all).json()
c = json.dumps(response1, indent=2)
print(c)
# Out:
# {
#   "Active Cases_text": "+20,048",
#   "Country_text": "World",
#   "Last Update": "2023-07-04 06:19",
#   "New Cases_text": "+15",
#   "New Deaths_text": "0",
#   "Total Cases_text": "690,985,847",
#   "Total Deaths_text": "6,896,157",
#   "Total Recovered_text": "663,652,718"
# }

# %%
#banyaknya negara
def hitung_banyak_dict_dalam_json(x):
    data = json.loads(x)
    count = 0
    if isinstance(data, list):
        for elemen in data:
            if isinstance(elemen, dict):
                count += 1
    return count

banyak_dict = hitung_banyak_dict_dalam_json(x)
print(banyak_dict)
# Out:
# 233

# %%
all_data = []
for lop in range(banyak_dict-1):
    data = response[lop]
    all_data.append(data)
all_data
# Out:
# [{'Active Cases_text': '+20,048',
#   'Country_text': 'World',
#   'Last Update': '2023-07-04 06:19',
#   'New Cases_text': '+15',
#   'New Deaths_text': '0',
#   'Total Cases_text': '690,985,847',
#   'Total Deaths_text': '6,896,157',
#   'Total Recovered_text': '663,652,718'},
#  {'Active Cases_text': '',
#   'Country_text': 'USA',
#   'Last Update': '2023-07-04 06:19',
#   'New Cases_text': '',
#   'New Deaths_text': '',
#   'Total Cases_text': '107,329,712',
#   'Total Deaths_text': '1,168,267',
#   'Total Recovered_text': '105,479,716'},
#  {'Active Cases_text': '',
#   'Country_text': 'India',
#   'Last Update': '2023-07-04 06:19',
#   'New Cases_text': '',
#   'New Deaths_text': '',
#   'Total Cases_text': '44,994,281',
#   'Total Deaths_text': '531,907',
#   'Total Recovered_text': '44,460,884'},
#  {'Active Cases_text': '+2,631',
#   'Country_text': 'France',
#   'Last Update': '2023-07-04 04:18',
#   'New Cases_text': '',
#   'New Deaths_text': '',
# ...

# %% [markdown]
# ### Cleansing Data

# %%
df = pd.DataFrame(all_data)
df
# Out:
#     Active Cases_text      Country_text       Last Update New Cases_text
# 0             +20,048             World  2023-07-04 06:19            +15  \
# 1                                   USA  2023-07-04 06:19
# 2                                 India  2023-07-04 06:19
# 3              +2,631            France  2023-07-04 04:18
# 4                               Germany  2023-07-04 06:19
# ..                ...               ...               ...            ...
# 227                    Diamond Princess  2023-05-30 07:08
# 228                        Vatican City  2023-05-30 07:08
# 229                             Tokelau  2023-05-30 07:08
# 230                      Western Sahara  2023-05-30 07:08
# 231                          MS Zaandam  2023-05-30 07:08
#
#     New Deaths_text Total Cases_text Total Deaths_text Total Recovered_text
# 0                 0      690,985,847         6,896,157          663,652,718
# ...

# %%
df['New Cases_text'] = df['New Cases_text'].replace([''], 0)
df['New Deaths_text'] = df['New Deaths_text'].replace([''], 0)
df['Total Cases_text'] = df['Total Cases_text'].replace([''], 0)
df['Total Deaths_text'] = df['Total Deaths_text'].replace([''], 0)
df['Total Recovered_text'] = df['Total Recovered_text'].replace([''], 0)
df['Total Recovered_text'] = df['Total Recovered_text'].replace(['N/A'], 0)
df['Active Cases_text'] = df['Active Cases_text'].str.replace('+', '')
df['Active Cases_text'] = df['Active Cases_text'].str.replace('N/A', '0')
df['Active Cases_text'] = df['Active Cases_text'].replace('', '0')
df = df.replace(',','', regex=True)
df.head(10)
# Out:
#   Active Cases_text Country_text       Last Update New Cases_text
# 0             20048        World  2023-07-04 06:19            +15  \
# 1                 0          USA  2023-07-04 06:19              0
# 2                 0        India  2023-07-04 06:19              0
# 3              2631       France  2023-07-04 04:18              0
# 4                 0      Germany  2023-07-04 06:19              0
# 5                 0       Brazil  2023-07-04 01:16              0
# 6                 0        Japan  2023-07-04 01:16              0
# 7             16493     S. Korea  2023-07-03 02:08              0
# 8                 0        Italy  2023-07-04 01:16              0
# 9                 0           UK  2023-07-03 23:15              0
#
#   New Deaths_text Total Cases_text Total Deaths_text Total Recovered_text
# 0               0        690985847           6896157            663652718
# 1               0        107329712           1168267            105479716
# ...

# %%
df['Last Update'] = pd.to_datetime(df['Last Update'])
df = df.astype({
    'Active Cases_text' : 'int',
    'New Cases_text' : 'int', 
    'New Deaths_text' : 'int', 
    'Total Cases_text' : 'int64', 
    'Total Deaths_text' : 'int', 
    'Total Recovered_text':'int'})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232 entries, 0 to 231
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Active Cases_text     232 non-null    int32
#  1   Country_text          232 non-null    object
#  2   Last Update           232 non-null    datetime64[ns]
#  3   New Cases_text        232 non-null    int32
#  4   New Deaths_text       232 non-null    int32
#  5   Total Cases_text      232 non-null    int64
#  6   Total Deaths_text     232 non-null    int32
#  7   Total Recovered_text  232 non-null    int32
# dtypes: datetime64[ns](1), int32(5), int64(1), object(1)
# memory usage: 10.1+ KB

# %%
Country_id = []
for x in range(banyak_dict-1):
    Country_id.append(x)

df['Country_ID'] = Country_id
df
# Out:
#      Active Cases_text      Country_text         Last Update  New Cases_text
# 0                20048             World 2023-07-04 06:19:00              15  \
# 1                    0               USA 2023-07-04 06:19:00               0
# 2                    0             India 2023-07-04 06:19:00               0
# 3                 2631            France 2023-07-04 04:18:00               0
# 4                    0           Germany 2023-07-04 06:19:00               0
# ..                 ...               ...                 ...             ...
# 227                  0  Diamond Princess 2023-05-30 07:08:00               0
# 228                  0      Vatican City 2023-05-30 07:08:00               0
# 229                  0           Tokelau 2023-05-30 07:08:00               0
# 230                  0    Western Sahara 2023-05-30 07:08:00               0
# 231                  0        MS Zaandam 2023-05-30 07:08:00               0
#
# ...

# %% [markdown]
# ### Tabel Country

# %%
df_Country = df[['Country_ID', 'Country_text']]
df_Country
# Out:
#      Country_ID      Country_text
# 0             0             World
# 1             1               USA
# 2             2             India
# 3             3            France
# 4             4           Germany
# ..          ...               ...
# 227         227  Diamond Princess
# 228         228      Vatican City
# 229         229           Tokelau
# 230         230    Western Sahara
# 231         231        MS Zaandam
#
# [232 rows x 2 columns]

# %% [markdown]
# ### Tabel Active Cases

# %%
df_Active_Cases = df[(df["Active Cases_text"]!=0) & (df['Active Cases_text'] != 'N/A')].reset_index()
df_Active_Cases
# Out:
#    index  Active Cases_text Country_text         Last Update  New Cases_text
# 0      0              20048        World 2023-07-04 06:19:00              15  \
# 1      3               2631       France 2023-07-04 04:18:00               0
# 2      7              16493     S. Korea 2023-07-03 02:08:00               0
# 3     33                626       Canada 2023-07-04 05:18:00               0
# 4     42                 50       Sweden 2023-07-04 05:18:00               0
# 5     43                156       Serbia 2023-07-04 06:19:00               0
# 6     55                 92      Finland 2023-07-03 23:15:00               0
#
#    New Deaths_text  Total Cases_text  Total Deaths_text  Total Recovered_text
# 0                0         690985847            6896157             663652718  \
# 1                0          40138560             167642              39948906
# 2                0          32131606              35017              31945015
# ...

# %%
df_Active_Cases = df_Active_Cases[['Country_ID', 'Active Cases_text','Total Cases_text','Total Recovered_text', 'Last Update']]

df_Active_Cases
# Out:
#    Country_ID  Active Cases_text  Total Cases_text  Total Recovered_text
# 0           0              20048         690985847             663652718  \
# 1           3               2631          40138560              39948906
# 2           7              16493          32131606              31945015
# 3          33                626           4688830               4628397
# 4          42                 50           2712743               2686603
# 5          43                156           2544001               2525128
# 6          55                 92           1482363               1471256
#
#           Last Update
# 0 2023-07-04 06:19:00
# 1 2023-07-04 04:18:00
# 2 2023-07-03 02:08:00
# 3 2023-07-04 05:18:00
# 4 2023-07-04 05:18:00
# 5 2023-07-04 06:19:00
# 6 2023-07-03 23:15:00

# %% [markdown]
# ### Tabel New Case Data

# %%
df_cases = df[(df['New Cases_text'] != 0 ) & (df['New Cases_text'] != 'N/A')]
df_cases
# Out:
#      Active Cases_text Country_text         Last Update  New Cases_text
# 0                20048        World 2023-07-04 06:19:00              15  \
# 114                  0         Laos 2023-07-03 23:15:00              15
#
#      New Deaths_text  Total Cases_text  Total Deaths_text
# 0                  0         690985847            6896157  \
# 114                0            218506                758
#
#      Total Recovered_text  Country_ID
# 0               663652718           0
# 114                     0         114

# %%
df_cases = df_cases[['Country_ID', 'New Cases_text','Last Update']]
df_cases
# Out:
#      Country_ID  New Cases_text         Last Update
# 0             0              15 2023-07-04 06:19:00
# 114         114              15 2023-07-03 23:15:00

# %% [markdown]
# ### Tabel Death Case

# %%
df_Death = df[(df['New Deaths_text'] != 0 ) & (df['New Deaths_text'] != 'N/A')].reset_index()
df_Death
# Out:
# Empty DataFrame
# Columns: [index, Active Cases_text, Country_text, Last Update, New Cases_text, New Deaths_text, Total Cases_text, Total Deaths_text, Total Recovered_text, Country_ID]
# Index: []

# %%
df_Death = df_Death[['Country_ID', 'New Deaths_text', 'Total Deaths_text', 'Last Update']]
df_Death
# Out:
# Empty DataFrame
# Columns: [Country_ID, New Deaths_text, Total Deaths_text, Last Update]
# Index: []

# %%
list_df = df_Active_Cases.values.tolist()
list_df
# Out:
# [[0, 20048, 690985847, 663652718, Timestamp('2023-07-04 06:19:00')],
#  [3, 2631, 40138560, 39948906, Timestamp('2023-07-04 04:18:00')],
#  [7, 16493, 32131606, 31945015, Timestamp('2023-07-03 02:08:00')],
#  [33, 626, 4688830, 4628397, Timestamp('2023-07-04 05:18:00')],
#  [42, 50, 2712743, 2686603, Timestamp('2023-07-04 05:18:00')],
#  [43, 156, 2544001, 2525128, Timestamp('2023-07-04 06:19:00')],
#  [55, 92, 1482363, 1471256, Timestamp('2023-07-03 23:15:00')]]

# %%
values_data = []
for i in df_Active_Cases:
    print(i)
# Out:
# Country_ID
# Active Cases_text
# Total Cases_text
# Total Recovered_text
# Last Update

# %%
from sqlalchemy import create_engine

host = "localhost"
user = "root"
password = '354354'
database = "data_engineer"
port = 3306

engine = create_engine(f'mysql://{user}:{password}@{host}:{port}/{database}')

# Ganti 'nama_tabel' dengan nama tabel yang diinginkan
df_Active_Cases.to_sql('active_case_test1', con=engine, if_exists='append', index=False)
# Out:
# 7

# %%
from sqlalchemy import create_engine
# Ganti 'mysql://user:password@host:port/database' dengan informasi koneksi Anda

host="localhost",
user="root",
password='354354',
database="data_engineer"
engine = create_engine(f'mysql://{user}:{password}@127.0.0.1:3306/{database}')

# Ganti 'nama_tabel' dengan nama tabel yang diinginkan
df_Active_Cases.to_sql('active_case_test', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\sqlalchemy\engine\base.py:3366, in Engine._wrap_pool_connect(self, fn, connection)
#    3365 try:
# -> 3366     return fn()
#    3367 except dialect.dbapi.Error as e:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sqlalchemy\pool\base.py:327, in Pool.connect(self)
#     320 """Return a DBAPI connection from the pool.
#     321
#     322 The connection is instrumented such that when its
#    (...)
#     325
#     326 """
# --> 327 return _ConnectionFairy._checkout(self)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sqlalchemy\pool\base.py:894, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     893 if not fairy:
# --> 894     fairy = _ConnectionRecord.checkout(pool)
#     896     fairy._pool = pool
#
# ...

# %%
import mysql.connector



mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="354354",
  database="data_engineer"
)


mycursor = mydb.cursor()

cursor = mydb.cursor()
sql = '''
    CREATE TABLE active_case_test(
    country_id int primary key,
    active_case int,
    total_case int,
    total_recovered int,
    last_update datetime
    )
    '''
sql_insert = '''
    insert into active_case values (%s, %s, %s, %s, %s)
    '''
values = (list_df)

cursor.execute(sql_insert, values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\mysql\connector\cursor.py:467, in MySQLCursor._process_params(self, params)
#     465 quote = self._connection.converter.quote
# --> 467 res = [to_mysql(value) for value in res]
#     468 res = [escape(value) for value in res]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\mysql\connector\cursor.py:467, in <listcomp>(.0)
#     465 quote = self._connection.converter.quote
# --> 467 res = [to_mysql(value) for value in res]
#     468 res = [escape(value) for value in res]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\mysql\connector\conversion.py:223, in MySQLConverter.to_mysql(self, value)
#     222     return str(value).encode()
# --> 223 raise TypeError(
#     224     f"Python '{type_name}' cannot be converted to a MySQL type"
#     225 ) from None
#
# ...

# %% [markdown]
# ### LOAD
